# %% [markdown]
# # <Topic Name> — Visual Experiments
#
# > **Goal:** Build geometric intuition through experiments — not just equations.
#
# ## What we'll explore
#
# | # | Experiment | Question answered |
# |---|---|---|
# | 1 | **<Experiment 1 name>** | <What does it show?> |
# | 2 | **<Experiment 2 name>** | <What does it show?> |
# | 3 | **<Experiment 3 name>** | <What does it show?> |
#
# ---
# **Linked theory:** `research/NN-concept-name.md`

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')

np.random.seed(42)
plt.rcParams.update({
    'figure.dpi': 110,
    'font.size': 11,
    'axes.titlesize': 12,
    'axes.labelsize': 11,
    'figure.facecolor': 'white',
    'axes.facecolor': '#f8f9fa',
    'axes.grid': True,
    'grid.alpha': 0.35,
})
print('Setup complete.')

# %% [markdown]
# ---
# ## Experiment 1: <Descriptive Title>
#
# **Question:** <State the exact question this experiment answers.>
#
# <1–3 sentence theory hook — what concept from the research file are we testing, and why does it matter?>

# %%
# --- Data / Parameter Setup ---
# Keep this cell pure setup: generate data, set parameters.
# No plotting here.
np.random.seed(1)

# example:
n = 500
X = np.random.randn(n, 2)
print(f'Dataset: {X.shape}')

# %%
# --- Visualization ---
fig, axes = plt.subplots(1, 2, figsize=(13, 5))
fig.suptitle('<Experiment 1 title>', fontsize=13, fontweight='bold')

ax = axes[0]
ax.scatter(X[:, 0], X[:, 1], alpha=0.4, s=12)
ax.set_xlabel('<X label>')
ax.set_ylabel('<Y label>')
ax.set_title('<Subplot title>')

ax2 = axes[1]
# second plot ...
ax2.set_xlabel('<X label>')
ax2.set_ylabel('<Y label>')
ax2.set_title('<Subplot title>')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### What you see
#
# <Required: explain the output above. Answer these three things:>
#
# 1. **What the plot shows:** <Describe the visual pattern — what shape, what trend, what value?>
# 2. **Why it looks this way:** <Connect to the theory from the research file.>
# 3. **Key takeaway:** <One sentence a reader should remember.>

# %% [markdown]
# ---
# ## Experiment 2: <Descriptive Title>
#
# **Question:** <State the exact question this experiment answers.>
#
# <Theory hook>

# %%
np.random.seed(2)
# setup ...

# %%
# visualization ...

# %% [markdown]
# ### What you see
#
# 1. **What the plot shows:** ...
# 2. **Why it looks this way:** ...
# 3. **Key takeaway:** ...

# %% [markdown]
# ---
# ## Summary
#
# | Experiment | Key insight |
# |---|---|
# | 1. <name> | <one-line takeaway> |
# | 2. <name> | <one-line takeaway> |
# | 3. <name> | <one-line takeaway> |
#
# ### Connection to the broader theory
#
# <Optional: 2–3 sentences connecting these experiments back to the research file and forward
# to what comes next in the curriculum.>
